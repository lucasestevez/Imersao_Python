# %% [markdown]
# **Aula 2 - Importação**

# %%
import pandas as pd

# %%
df_principal = pd.read_excel("/content/Aula 2 - Imersão Python.xlsx", sheet_name="Principal")
df_principal

# %%
df_total_acoes = pd.read_excel("/content/Aula 2 - Imersão Python.xlsx", sheet_name="Total_de_acoes")
df_total_acoes

# %%
df_tickers = pd.read_excel("/content/Aula 2 - Imersão Python.xlsx", sheet_name="Tickers")
df_tickers

# %%
df_chatGPT = pd.read_excel("/content/Aula 2 - Imersão Python.xlsx", sheet_name="ChatGPT")
df_chatGPT

# %%
df_analises = pd.read_excel("/content/Aula 2 - Imersão Python.xlsx", sheet_name="Análises")
df_analises
